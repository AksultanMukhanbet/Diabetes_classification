# %% [markdown]
# # Медициналық жағдайларға байланысты қант диабетін түсіну және болжау.

# %% [markdown]
# # кітапханаларды импорттау

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sweetviz as sv
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix


# %matplotlib inline

# %% [markdown]
# # Plot баптаулары

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 23
plt.rcParams['figure.titlesize'] = 26
plt.rcParams['xtick.major.size'] = 10
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['ytick.major.size'] = 10
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.minor.size'] = 5
plt.rcParams['ytick.minor.width'] = 1
plt.rcParams['xtick.minor.size'] = 5
plt.rcParams['figure.figsize'] = 7,4
sns.set_style('ticks')

# %% [markdown]
# # Мәліметтерді оқу

# %%
csv_file='diabetes.csv'
df = pd.read_csv(csv_file)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.iloc[:,:-1].describe().style.background_gradient(axis=0,cmap='Accent')
# Out:
# <style  type="text/css" >
# #T_56c67_row0_col0,#T_56c67_row0_col1,#T_56c67_row0_col2,#T_56c67_row0_col3,#T_56c67_row0_col4,#T_56c67_row0_col5,#T_56c67_row0_col6,#T_56c67_row0_col7,#T_56c67_row7_col4{
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }#T_56c67_row1_col0,#T_56c67_row1_col2,#T_56c67_row1_col3,#T_56c67_row1_col4,#T_56c67_row1_col5,#T_56c67_row1_col6,#T_56c67_row1_col7,#T_56c67_row2_col0,#T_56c67_row2_col1,#T_56c67_row2_col2,#T_56c67_row2_col3,#T_56c67_row2_col5,#T_56c67_row2_col6,#T_56c67_row2_col7,#T_56c67_row3_col0,#T_56c67_row3_col1,#T_56c67_row3_col2,#T_56c67_row3_col3,#T_56c67_row3_col4,#T_56c67_row3_col5,#T_56c67_row3_col6,#T_56c67_row3_col7,#T_56c67_row4_col0,#T_56c67_row4_col2,#T_56c67_row4_col3,#T_56c67_row4_col4,#T_56c67_row4_col5,#T_56c67_row4_col6,#T_56c67_row4_col7,#T_56c67_row5_col0,#T_56c67_row5_col2,#T_56c67_row5_col3,#T_56c67_row5_col4,#T_56c67_row5_col5,#T_56c67_row5_col6,#T_56c67_row5_col7,#T_56c67_row6_col0,#T_56c67_row6_col2,#T_56c67_row6_col3,#T_56c67_row6_col5,#T_56c67_row6_col6,#T_56c67_row6_col7,#T_56c67_row7_col0,#T_56c67_row7_col5,#T_56c67_row7_col6,#T_56c67_row7_col7{
#             background-color:  #7fc97f;
#             color:  #000000;
#         }#T_56c67_row1_col1,#T_56c67_row2_col4,#T_56c67_row4_col1,#T_56c67_row5_col1,#T_56c67_row6_col1,#T_56c67_row6_col4,#T_56c67_row7_col2,#T_56c67_row7_col3{
#             background-color:  #beaed4;
#             color:  #000000;
#         }#T_56c67_row7_col1{
#             background-color:  #fdc086;
#             color:  #000000;
#         }</style><table id="T_56c67_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Pregnancies</th>        <th class="col_heading level0 col1" >Glucose</th>        <th class="col_heading level0 col2" >BloodPressure</th>        <th class="col_heading level0 col3" >SkinThickness</th>        <th class="col_heading level0 col4" >Insulin</th>        <th class="col_heading level0 col5" >BMI</th>        <th class="col_heading level0 col6" >DiabetesPedigreeFunction</th>        <th class="col_heading level0 col7" >Age</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_56c67_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_56c67_row0_col0" class="data row0 col0" >768.000000</td>
#                         <td id="T_56c67_row0_col1" class="data row0 col1" >768.000000</td>
#                         <td id="T_56c67_row0_col2" class="data row0 col2" >768.000000</td>
#                         <td id="T_56c67_row0_col3" class="data row0 col3" >768.000000</td>
#                         <td id="T_56c67_row0_col4" class="data row0 col4" >768.000000</td>
#                         <td id="T_56c67_row0_col5" class="data row0 col5" >768.000000</td>
#                         <td id="T_56c67_row0_col6" class="data row0 col6" >768.000000</td>
#                         <td id="T_56c67_row0_col7" class="data row0 col7" >768.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_56c67_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_56c67_row1_col0" class="data row1 col0" >3.845052</td>
#                         <td id="T_56c67_row1_col1" class="data row1 col1" >120.894531</td>
#                         <td id="T_56c67_row1_col2" class="data row1 col2" >69.105469</td>
#                         <td id="T_56c67_row1_col3" class="data row1 col3" >20.536458</td>
#                         <td id="T_56c67_row1_col4" class="data row1 col4" >79.799479</td>
#                         <td id="T_56c67_row1_col5" class="data row1 col5" >31.992578</td>
#                         <td id="T_56c67_row1_col6" class="data row1 col6" >0.471876</td>
#                         <td id="T_56c67_row1_col7" class="data row1 col7" >33.240885</td>
#             </tr>
#             <tr>
#                         <th id="T_56c67_level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_56c67_row2_col0" class="data row2 col0" >3.369578</td>
#                         <td id="T_56c67_row2_col1" class="data row2 col1" >31.972618</td>
#                         <td id="T_56c67_row2_col2" class="data row2 col2" >19.355807</td>
#                         <td id="T_56c67_row2_col3" class="data row2 col3" >15.952218</td>
#                         <td id="T_56c67_row2_col4" class="data row2 col4" >115.244002</td>
#                         <td id="T_56c67_row2_col5" class="data row2 col5" >7.884160</td>
#                         <td id="T_56c67_row2_col6" class="data row2 col6" >0.331329</td>
#                         <td id="T_56c67_row2_col7" class="data row2 col7" >11.760232</td>
#             </tr>
#             <tr>
#                         <th id="T_56c67_level0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_56c67_row3_col0" class="data row3 col0" >0.000000</td>
#                         <td id="T_56c67_row3_col1" class="data row3 col1" >0.000000</td>
#                         <td id="T_56c67_row3_col2" class="data row3 col2" >0.000000</td>
#                         <td id="T_56c67_row3_col3" class="data row3 col3" >0.000000</td>
#                         <td id="T_56c67_row3_col4" class="data row3 col4" >0.000000</td>
#                         <td id="T_56c67_row3_col5" class="data row3 col5" >0.000000</td>
#                         <td id="T_56c67_row3_col6" class="data row3 col6" >0.078000</td>
#                         <td id="T_56c67_row3_col7" class="data row3 col7" >21.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_56c67_level0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_56c67_row4_col0" class="data row4 col0" >1.000000</td>
#                         <td id="T_56c67_row4_col1" class="data row4 col1" >99.000000</td>
#                         <td id="T_56c67_row4_col2" class="data row4 col2" >62.000000</td>
#                         <td id="T_56c67_row4_col3" class="data row4 col3" >0.000000</td>
#                         <td id="T_56c67_row4_col4" class="data row4 col4" >0.000000</td>
#                         <td id="T_56c67_row4_col5" class="data row4 col5" >27.300000</td>
#                         <td id="T_56c67_row4_col6" class="data row4 col6" >0.243750</td>
#                         <td id="T_56c67_row4_col7" class="data row4 col7" >24.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_56c67_level0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_56c67_row5_col0" class="data row5 col0" >3.000000</td>
#                         <td id="T_56c67_row5_col1" class="data row5 col1" >117.000000</td>
#                         <td id="T_56c67_row5_col2" class="data row5 col2" >72.000000</td>
#                         <td id="T_56c67_row5_col3" class="data row5 col3" >23.000000</td>
#                         <td id="T_56c67_row5_col4" class="data row5 col4" >30.500000</td>
#                         <td id="T_56c67_row5_col5" class="data row5 col5" >32.000000</td>
#                         <td id="T_56c67_row5_col6" class="data row5 col6" >0.372500</td>
#                         <td id="T_56c67_row5_col7" class="data row5 col7" >29.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_56c67_level0_row6" class="row_heading level0 row6" >75%</th>
#                         <td id="T_56c67_row6_col0" class="data row6 col0" >6.000000</td>
#                         <td id="T_56c67_row6_col1" class="data row6 col1" >140.250000</td>
#                         <td id="T_56c67_row6_col2" class="data row6 col2" >80.000000</td>
#                         <td id="T_56c67_row6_col3" class="data row6 col3" >32.000000</td>
#                         <td id="T_56c67_row6_col4" class="data row6 col4" >127.250000</td>
#                         <td id="T_56c67_row6_col5" class="data row6 col5" >36.600000</td>
#                         <td id="T_56c67_row6_col6" class="data row6 col6" >0.626250</td>

# %%
df.head(10).style.bar(axis=0)
# Out:
# <style  type="text/css" >
# #T_679d5_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 60.0%, transparent 60.0%);
#         }#T_679d5_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 58.8%, transparent 58.8%);
#         }#T_679d5_row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 75.0%, transparent 75.0%);
#         }#T_679d5_row0_col3,#T_679d5_row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 77.8%, transparent 77.8%);
#         }#T_679d5_row0_col4,#T_679d5_row1_col4,#T_679d5_row1_col8,#T_679d5_row2_col3,#T_679d5_row2_col4,#T_679d5_row3_col7,#T_679d5_row3_col8,#T_679d5_row4_col0,#T_679d5_row5_col3,#T_679d5_row5_col4,#T_679d5_row5_col8,#T_679d5_row6_col1,#T_679d5_row7_col2,#T_679d5_row7_col3,#T_679d5_row7_col4,#T_679d5_row7_col6,#T_679d5_row7_col8,#T_679d5_row9_col3,#T_679d5_row9_col4,#T_679d5_row9_col5{
#             width:  10em;
#              height:  80%;
#         }#T_679d5_row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 78.0%, transparent 78.0%);
#         }#T_679d5_row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 22.9%, transparent 22.9%);
#         }#T_679d5_row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 87.9%, transparent 87.9%);
#         }#T_679d5_row0_col8,#T_679d5_row2_col8,#T_679d5_row4_col5,#T_679d5_row4_col6,#T_679d5_row4_col8,#T_679d5_row6_col8,#T_679d5_row7_col0,#T_679d5_row8_col1,#T_679d5_row8_col3,#T_679d5_row8_col4,#T_679d5_row8_col8,#T_679d5_row9_col2,#T_679d5_row9_col7,#T_679d5_row9_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_679d5_row1_col0,#T_679d5_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.0%, transparent 10.0%);
#         }#T_679d5_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.9%, transparent 5.9%);
#         }#T_679d5_row1_col2,#T_679d5_row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 68.7%, transparent 68.7%);
#         }#T_679d5_row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 64.4%, transparent 64.4%);
#         }#T_679d5_row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 61.7%, transparent 61.7%);
#         }#T_679d5_row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.1%, transparent 10.1%);
#         }#T_679d5_row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 30.3%, transparent 30.3%);
#         }#T_679d5_row2_col0,#T_679d5_row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 80.0%, transparent 80.0%);
#         }#T_679d5_row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 88.2%, transparent 88.2%);
#         }#T_679d5_row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 66.7%, transparent 66.7%);
#         }#T_679d5_row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 54.1%, transparent 54.1%);
#         }#T_679d5_row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.0%, transparent 25.0%);
#         }#T_679d5_row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.3%, transparent 33.3%);
#         }#T_679d5_row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.2%, transparent 9.2%);
#         }#T_679d5_row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 51.1%, transparent 51.1%);
#         }#T_679d5_row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.3%, transparent 17.3%);
#         }#T_679d5_row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 65.2%, transparent 65.2%);
#         }#T_679d5_row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.5%, transparent 1.5%);
#         }#T_679d5_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 49.6%, transparent 49.6%);
#         }#T_679d5_row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 41.7%, transparent 41.7%);
#         }#T_679d5_row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 30.9%, transparent 30.9%);
#         }#T_679d5_row4_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 36.4%, transparent 36.4%);
#         }#T_679d5_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 50.0%, transparent 50.0%);
#         }#T_679d5_row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.9%, transparent 31.9%);
#         }#T_679d5_row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 77.1%, transparent 77.1%);
#         }#T_679d5_row5_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 59.4%, transparent 59.4%);
#         }#T_679d5_row5_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.1%, transparent 3.1%);
#         }#T_679d5_row5_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 27.3%, transparent 27.3%);
#         }#T_679d5_row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 30.0%, transparent 30.0%);
#         }#T_679d5_row6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 52.1%, transparent 52.1%);
#         }#T_679d5_row6_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 71.1%, transparent 71.1%);
#         }#T_679d5_row6_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.2%, transparent 16.2%);
#         }#T_679d5_row6_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 71.9%, transparent 71.9%);
#         }#T_679d5_row6_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.3%, transparent 5.3%);
#         }#T_679d5_row6_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.2%, transparent 15.2%);
#         }#T_679d5_row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.1%, transparent 31.1%);
#         }

# %% [markdown]
# # Зерттеу деректерін талдау (EDA)

# %%
print("dimension of diabetes data: {}".format(df.shape))
# Out:
# dimension of diabetes data: (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# * Деректер жиыны шағын және жақсы таңбаланған. Нөлдік мәндер жоқ.
# * басқарылатын машиналық оқыту тұжырымдамасына өте қолайлы.
# * Бұл екілік классификация мәселесі, мұнда бізде мақсат ** (y) ** бойынша 2 сынып бар (яғни df ['Нәтиже'] `) және медициналық жағдайлар (** X **) ретінде қолданыла алады ).

# %% [markdown]
# ## Sweetviz бақылау тақтасы

# %%
sv.analyze([df,'Diabetes data' ], target_feat='Outcome').show_html()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, layout=Layout(flex='2'), max=10.0), HTML(value='')), l…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## Барлық сипаттамаларды біріктіру

# %%
sns.pairplot(df.iloc[:,:-1], diag_kind='hist')

# %% [markdown]
# ## Пирсон корреляциясы және признактарды таңдау

# %%
plt.figure(figsize=(10,7))
corr_mat = df.iloc[:,:-1].corr()
sns.heatmap(corr_mat, fmt='0.2f', annot=True, lw=2, cbar_kws={'label':'Pearson Correlation (r)'})
plt.xticks(size=15,rotation=90)
plt.yticks(size=15)
plt.tight_layout()
plt.savefig('Correlation.png',dpi=300);

# %% [markdown]
# * Барлық мүмкіндіктер бір-бірімен өте аз корреляцияға ие. Тек жасы мен жүктілігі айтарлықтай күшті корреляцияны көрсетеді. Сондықтан барлық ерекшеліктерді сақтай отырып.

# %% [markdown]
# ## Қант диабеті деректер жиынтығындағы таралу

# %%
plt.figure(figsize=(5,5))
sns.countplot(df['Outcome'],label='Count')
plt.xticks(size=15)
plt.yticks(size=15)
plt.ylabel('Outcome',size=15)
plt.xlabel('Count',size=15)
sns.despine(top=True)
plt.title('Class distribution',size=26, weight='bold')
plt.tight_layout()
plt.savefig('Class-distribution.png');
# Out:
# C:\Users\aksultan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Мәліметтерді машиналық оқытуға дайындау

# %%
X = df.iloc[:,:-1].values   ##features selection
y = df.iloc[:,-1].values    ## target selection

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=y, random_state=27)

# %% [markdown]
# * ** train_test_split ** ішінде stratify қолдану мүмкін емес. Ол пойыздарда және тестілеу деректер жиынтығында бірдей мақсатты бөлуді сақтайды. егер `y` айнымалысы 0 және 1 мәндері бар екілік категориялық айнымалы болса және нөлдердің 25% -ы және 75% -ы болса,` stratify = y` кездейсоқ бөлінудің 0-ден 40% және 1-ден 60% болатындығына көз жеткізеді

# %% [markdown]
# # Машиналық оқыту модельдері

# %% [markdown]
# ## k-Nearest Neighbors (KNN)

# %%
training_accuracy = [] 
test_accuracy = []
training_f1 = []
test_f1 = []

neighbors_settings = range(2,40)

for n_neighbors in neighbors_settings:
    print(f'working on neighbors {n_neighbors}')
    knn = KNeighborsClassifier(n_neighbors=n_neighbors)
    knn.fit(X_train, y_train)
    
    y_train_pred=knn.predict(X_train)
    y_pred=knn.predict(X_test)
    
    training_accuracy.append(accuracy_score(y_train,y_train_pred))
    test_accuracy.append(accuracy_score(y_test, y_pred))
    
    training_f1.append(f1_score(y_train,y_train_pred))
    test_f1.append(f1_score(y_test, y_pred))
# Out:
# working on neighbors 2
# working on neighbors 3
# working on neighbors 4
# working on neighbors 5
# working on neighbors 6
# working on neighbors 7
# working on neighbors 8
# working on neighbors 9
# working on neighbors 10
# working on neighbors 11
# working on neighbors 12
# working on neighbors 13
# working on neighbors 14
# working on neighbors 15
# working on neighbors 16
# working on neighbors 17
# working on neighbors 18
# working on neighbors 19
# working on neighbors 20
# working on neighbors 21
# working on neighbors 22
# working on neighbors 23
# working on neighbors 24
# working on neighbors 25
# working on neighbors 26
# working on neighbors 27
# working on neighbors 28
# working on neighbors 29
# working on neighbors 30
# working on neighbors 31
# working on neighbors 32
# working on neighbors 33
# working on neighbors 34
# working on neighbors 35
# working on neighbors 36
# working on neighbors 37
# working on neighbors 38
# working on neighbors 39

# %%
fig = plt.figure(figsize=(14,10))
fig.subplots_adjust(hspace=0.5, wspace=0.3)

fig.add_subplot(2,2,1)
plt.plot(neighbors_settings, training_accuracy, label='training accuracy')
plt.plot(neighbors_settings, test_accuracy, label='test accuracy')
plt.ylabel('Accuracy',size=20)
plt.xticks(size=15)
plt.yticks(size=15)
plt.xlabel('n_neighbors',size=20)
plt.title('Accuracy Score',size=20, weight='bold')
plt.legend([],frameon=False)

fig.add_subplot(2,2,2)
plt.plot(neighbors_settings, training_f1)
plt.plot(neighbors_settings, test_f1)
plt.xticks(size=15)
plt.yticks(size=15)
plt.ylabel('F1 Score',size=20)
plt.xlabel('n_neighbors',size=20)
plt.title('F1-Score',size=20,weight='bold')
plt.legend(['Training','Testing'],frameon=False, bbox_to_anchor=(0.4,-0.2), ncol=2);

# %% [markdown]
# `Accuracy score`, `F1-score` suggest that `n_neighbors=19` is the optimum choice **(by looking a testing accuracies)**.

# %%
knn = KNeighborsClassifier(n_neighbors=19).fit(X_train, y_train)
y_pred = knn.predict(X_test)

print('Accuracy of K-NN classifier on test set: {:.2f}'.format(knn.score(X_train, y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'.format(accuracy_score(y_test, y_pred)))
print('F1-score of K-NN classifier on test set: {:.2f}'.format(f1_score(y_test, y_pred)))
# Out:
# Accuracy of K-NN classifier on test set: 0.79
# Accuracy of K-NN classifier on test set: 0.71
# F1-score of K-NN classifier on test set: 0.56

# %% [markdown]
# ### Confusion matrix

# %%
def normalized_confusion_matrix(y_test, conf_mat, model):
    _ , counts = np.unique(y_test,return_counts=True)
    conf_mat = conf_mat/counts
    plt.figure(figsize=(6,5))
    ax=sns.heatmap(conf_mat,fmt='.2f',annot=True,annot_kws={'size':20},lw=2, cbar=True, cbar_kws={'label':'% Class accuracy'})
    plt.title(f'Confusion Matrix ({model})',size=22)
    plt.xticks(size=20)
    plt.yticks(size=20)
    ax.figure.axes[-1].yaxis.label.set_size(20) ##colorbar label
    cax = plt.gcf().axes[-1]  ##colorbar ticks
    cax.tick_params(labelsize=20) ## colorbar ticks
    plt.savefig(f'confusion-matrix-{model}.png',dpi=300)

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat, 'kNN')

# %% [markdown]
# ### K-fold cross validation

# %%
k_fold_knn_accuracy = cross_val_score(knn, X, y, cv=10) ##10-fold cross validation
k_fold_knn_f1 = cross_val_score(knn, X, y, cv=10, scoring='f1_macro') ##10-fold cross validation

# %%
print(f'Average accuracy after 10 fold cross validation :{k_fold_knn_accuracy.mean().round(2)} +/- {k_fold_knn_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation :{k_fold_knn_f1.mean().round(2)} +/- {k_fold_knn_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation :0.75 +/- 0.06
# Average F1-score after 10 fold cross validation :0.71 +/- 0.07

# %%
plt.figure(figsize=(8,6))
Clist=[1,0.01,100]

for C in Clist : 

    logreg = LogisticRegression(C=C,solver='newton-cg').fit(X_train, y_train) #keeping C=1 a
    y_train_pred = logreg.predict(X_train)
    y_pred = logreg.predict(X_test)

    print('C : {} Training set accuracy: {:.3f}'.format(C,accuracy_score(y_train, y_train_pred)))
    print('C : {} Test set accuracy: {:.3f}'.format(C,accuracy_score(y_test, y_pred)))

    print('C : {} Training set F1-score: {:.3f}'.format(C,f1_score(y_train, y_train_pred)))
    print('C : {} Test set F1-score: {:.3f}'.format(C, f1_score(y_test, y_pred)))
    print('\n')
    
    diabetes_features = [x for i,x in enumerate(df.columns) if i!=8]
    plt.plot(logreg.coef_.T, marker='o', label=f"C={C}")
# Out:
# C : 1 Training set accuracy: 0.778
# C : 1 Test set accuracy: 0.776
# C : 1 Training set F1-score: 0.646
# C : 1 Test set F1-score: 0.650
#
#
# C : 0.01 Training set accuracy: 0.776
# C : 0.01 Test set accuracy: 0.766
# C : 0.01 Training set F1-score: 0.645
# C : 0.01 Test set F1-score: 0.634
#
#
# C : 100 Training set accuracy: 0.774
# C : 100 Test set accuracy: 0.771
# C : 100 Training set F1-score: 0.641
# C : 100 Test set F1-score: 0.645

# %% [markdown]
# ## Decision Tree

# %%
max_depth=range(1,20)
training_accuracy = [] 
test_accuracy = []
training_f1 = []
test_f1 = []

for depth in max_depth : 
    tree = DecisionTreeClassifier(random_state=0, max_depth=depth, min_samples_leaf=1).fit(X_train, y_train)
    y_train_pred = tree.predict(X_train)
    y_pred = tree.predict(X_test)
    
    training_accuracy.append(accuracy_score(y_train,y_train_pred))
    test_accuracy.append(accuracy_score(y_test, y_pred))
    
    training_f1.append(f1_score(y_train,y_train_pred))
    test_f1.append(f1_score(y_test, y_pred))

# %%
fig = plt.figure(figsize=(14,10))
fig.subplots_adjust(hspace=0.5, wspace=0.3)

fig.add_subplot(2,2,1)
plt.plot(max_depth, training_accuracy, label='training accuracy')
plt.plot(max_depth, test_accuracy, label='test accuracy')
plt.ylabel('Accuracy',size=20)
plt.xlabel('Max depth',size=20)
plt.xticks(size=15)
plt.yticks(size=15)
plt.title('Accuracy Score',size=20, weight='bold')
plt.legend([],frameon=False)

fig.add_subplot(2,2,2)
plt.plot(max_depth, training_f1)
plt.plot(max_depth, test_f1)
plt.ylabel('F1 Score',size=20)
plt.xlabel('Max depth',size=20)
plt.xticks(size=15)
plt.yticks(size=15)
plt.title('F1-Score',size=20,weight='bold')
plt.legend(['Training','Testing'],frameon=False, bbox_to_anchor=(0.4,-0.2), ncol=2);

# %% [markdown]
# Үйретуден кейінгі жиынтықтағы уйрету дәлдігі 100% құрайды, ал тестілеу жиынтығының дәлдігі анағұрлым нашар. Бұл дегеніміз ағаш шамадан тыс сәйкес келеді және жаңа деректерді жалпылай алмайды. Біз «max_depth = 4» мәнін орнаттық, ағаштың тереңдігін шектеу шамадан тыс отыруды азайтады. Бұл үйрету жиынтығында дәлдіктің төмендеуіне, бірақ тест жиынтығының жақсаруына әкеледі.

# %%
tree = DecisionTreeClassifier(max_depth=4, min_samples_leaf=1, random_state=0).fit(X_train, y_train)
y_pred=tree.predict(X_test)

print("Accuracy on test: {:.3f}".format(accuracy_score(y_pred, y_test)))
print("F1-score on test set: {:.3f}".format(f1_score(y_pred, y_test)))
# Out:
# Accuracy on test: 0.724
# F1-score on test set: 0.624

# %% [markdown]
# ### Confusion matrix

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat,'Decision Tree')

# %% [markdown]
# ### K-fold cross validation

# %%
k_fold_tree_accuracy = cross_val_score(tree, X, y, cv=10) ##10-fold cross validation
k_fold_tree_f1 = cross_val_score(tree, X, y, cv=10, scoring='f1_macro') ##10-fold cross validation

# %%
print(f'Average accuracy after 10 fold cross validation :{k_fold_tree_accuracy.mean().round(2)} +/- {k_fold_tree_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation :{k_fold_tree_f1.mean().round(2)} +/- {k_fold_tree_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation :0.72 +/- 0.04
# Average F1-score after 10 fold cross validation :0.69 +/- 0.05

# %% [markdown]
# ### Шешім ағаштарындағы маңыздылық
# Функцияның маңыздылығы ағаштың шешім қабылдауы үшін әр функцияның қаншалықты маңызды екенін анықтайды. Бұл 0 мен 1 аралығындағы сан
#
#       0 «мүлдем қолданылмайды» дегенді білдіреді
#       1 «мақсатты жақсы болжайды» дегенді білдіреді

# %% [markdown]
# Особенность "Глюкозы" - это самая важная особенность.

# %% [markdown]
# ## Random Forest

# %%
rf = RandomForestClassifier(random_state=0).fit(X_train, y_train)
y_pred=rf.predict(X_test)

print("Accuracy on test: {:.3f}".format(accuracy_score(y_pred, y_test)))
print("F1-score on test set: {:.3f}".format(f1_score(y_pred, y_test)))
# Out:
# Accuracy on test: 0.740
# F1-score on test set: 0.603

# %% [markdown]
# ### Feature importance in Random Forest

# %%
plot_feature_importances(rf, 'Random Forest')

# %% [markdown]
# Шешім ағашы сияқты, кездейсоқ орман "Глюкоза" функциясына үлкен мән береді, сонымен қатар 2-ші ақпараттық белгі ретінде BMI-ді таңдайды.

# %% [markdown]
# ### Confusion matrix

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat,'Random Forest')

# %% [markdown]
# ### K-fold cross-validation

# %%
k_fold_rf_accuracy = cross_val_score(rf, X, y, cv=10) ##10-fold cross validation
k_fold_rf_f1 = cross_val_score(rf, X, y, cv=10, scoring='f1_macro') ##10-fold cross validation

# %%
print(f'Average accuracy after 10 fold cross validation :{k_fold_tree_accuracy.mean().round(2)} +/- {k_fold_tree_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation :{k_fold_tree_f1.mean().round(2)} +/- {k_fold_tree_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation :0.72 +/- 0.04
# Average F1-score after 10 fold cross validation :0.69 +/- 0.05

# %% [markdown]
# ## Support Vector Machine (SVM)

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

#SVM requiest feature scaling
svc = SVC(kernel='rbf').fit(X_train_scaled, y_train)
y_pred=svc.predict(X_test_scaled)

print("Accuracy on train: {:.3f}".format(svc.score(X_train_scaled, y_train)))
print("Accuracy on test: {:.3f}".format(accuracy_score(y_pred, y_test)))
print("F1-score on test set: {:.3f}".format(f1_score(y_pred, y_test)))
# Out:
# Accuracy on train: 0.799
# Accuracy on test: 0.755
# F1-score on test set: 0.544

# %% [markdown]
# ### Confusion matrix

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat,'SVM')

# %% [markdown]
# ### K-fold cross-validation

# %%
k_fold_svm_accuracy = cross_val_score(svc, scaler.fit_transform(X), y, cv=10) ##10-fold cross validation
k_fold_svm_f1 = cross_val_score(svc, scaler.fit_transform(X), y, cv=10, scoring='f1_macro') ##10-fold cross validation

# %%
print(f'Average accuracy after 10 fold cross validation : {k_fold_svm_accuracy.mean().round(2)} +/- {k_fold_svm_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation : {k_fold_svm_f1.mean().round(2)} +/- {k_fold_svm_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation : 0.77 +/- 0.03
# Average F1-score after 10 fold cross validation : 0.73 +/- 0.03

# %% [markdown]
# # Model comparision

# %%
all_accuracies = [k_fold_knn_accuracy.mean().round(2),
                   k_fold_tree_accuracy.mean().round(2),
                   k_fold_rf_accuracy.mean().round(2),
                   k_fold_svm_accuracy.mean().round(2)]

all_accuracies_errors = [k_fold_knn_accuracy.std().round(2),
                   k_fold_tree_accuracy.std().round(2),
                   k_fold_rf_accuracy.std().round(2),
                   k_fold_svm_accuracy.std().round(2)]

# %%
all_f1 = [k_fold_knn_accuracy.mean().round(2),
                   k_fold_tree_f1.mean().round(2),
                   k_fold_rf_f1.mean().round(2),
                   k_fold_svm_f1.mean().round(2)]

all_f1_errors = [k_fold_knn_f1.std().round(2),
                   k_fold_tree_f1.std().round(2),
                   k_fold_rf_f1.std().round(2),
                   k_fold_svm_f1.std().round(2)]

# %%
models=['kNN','Decision Tree','Random Forest','SVM']

# %%
model_data = pd.DataFrame([all_accuracies,all_accuracies_errors,all_f1,all_f1_errors],columns=models, index = ['Accuracy','STD_acc','F1-macro','STD_f1']).T

# %%
model_data.style.background_gradient(cmap='coolwarm',axis=0)
# Out:
# <style  type="text/css" >
# #T_9b3cf_row0_col0{
#             background-color:  #f4987a;
#             color:  #000000;
#         }#T_9b3cf_row0_col1,#T_9b3cf_row0_col2,#T_9b3cf_row0_col3,#T_9b3cf_row2_col0,#T_9b3cf_row2_col1,#T_9b3cf_row3_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_9b3cf_row1_col0,#T_9b3cf_row1_col2,#T_9b3cf_row3_col1,#T_9b3cf_row3_col3{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_9b3cf_row1_col1{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_9b3cf_row1_col3,#T_9b3cf_row3_col2{
#             background-color:  #dddcdc;
#             color:  #000000;
#         }#T_9b3cf_row2_col2{
#             background-color:  #f7b89c;
#             color:  #000000;
#         }#T_9b3cf_row2_col3{
#             background-color:  #f49a7b;
#             color:  #000000;
#         }</style><table id="T_9b3cf_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >STD_acc</th>        <th class="col_heading level0 col2" >F1-macro</th>        <th class="col_heading level0 col3" >STD_f1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b3cf_level0_row0" class="row_heading level0 row0" >kNN</th>
#                         <td id="T_9b3cf_row0_col0" class="data row0 col0" >0.750000</td>
#                         <td id="T_9b3cf_row0_col1" class="data row0 col1" >0.060000</td>
#                         <td id="T_9b3cf_row0_col2" class="data row0 col2" >0.750000</td>
#                         <td id="T_9b3cf_row0_col3" class="data row0 col3" >0.070000</td>
#             </tr>
#             <tr>
#                         <th id="T_9b3cf_level0_row1" class="row_heading level0 row1" >Decision Tree</th>
#                         <td id="T_9b3cf_row1_col0" class="data row1 col0" >0.720000</td>
#                         <td id="T_9b3cf_row1_col1" class="data row1 col1" >0.040000</td>
#                         <td id="T_9b3cf_row1_col2" class="data row1 col2" >0.690000</td>
#                         <td id="T_9b3cf_row1_col3" class="data row1 col3" >0.050000</td>
#             </tr>
#             <tr>
#                         <th id="T_9b3cf_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#                         <td id="T_9b3cf_row2_col0" class="data row2 col0" >0.760000</td>
#                         <td id="T_9b3cf_row2_col1" class="data row2 col1" >0.060000</td>
#                         <td id="T_9b3cf_row2_col2" class="data row2 col2" >0.730000</td>
#                         <td id="T_9b3cf_row2_col3" class="data row2 col3" >0.060000</td>
#             </tr>
#             <tr>
#                         <th id="T_9b3cf_level0_row3" class="row_heading level0 row3" >SVM</th>
#                         <td id="T_9b3cf_row3_col0" class="data row3 col0" >0.760000</td>
#                         <td id="T_9b3cf_row3_col1" class="data row3 col1" >0.030000</td>
#                         <td id="T_9b3cf_row3_col2" class="data row3 col2" >0.720000</td>
#                         <td id="T_9b3cf_row3_col3" class="data row3 col3" >0.030000</td>
#             </tr>
#     </tbody></table>

# %%
model_data[['Accuracy','F1-macro']].plot.barh(figsize=(10,7))
plt.legend(frameon=False,bbox_to_anchor=(0.7,0.8), prop={'size':20})
plt.xticks(size=15)
plt.yticks(size=15)
plt.xlim([0.65,0.8]);
plt.title('Model performances',size=20)
sns.despine(top=True)
plt.tight_layout()
plt.savefig('model-comparision.png',dpi=300)

# %%
plt.figure(figsize=(10,7))
diabetes_accuracy = all_accuracies
plt.barh(models,diabetes_accuracy, color='red',alpha=0.5)
plt.xticks(size=15)
plt.yticks(size=15)
plt.title('Accuracy in Diabetes Detection',size=20)
sns.despine(top=True)
plt.tight_layout()
plt.savefig('diabetes-detection.png',dpi=300)
